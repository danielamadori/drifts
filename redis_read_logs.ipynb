# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Redis Read Logs\n",
#     "\n",
#     "Analyze and read Redis logs."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import redis\n",
#     "import pandas as pd\n",
#     "\n",
#     "r = redis.Redis(host='localhost', port=6379, decode_responses=True)\n",
#     "print(f\"Redis connected: {r.ping()}\")"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Log analysis"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.11.0"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 4
# }
